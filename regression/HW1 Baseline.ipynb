# %% [markdown]
# # Baseline Code for HW1
#
# This is just the baseline code to set up the basic function you need. You need to modify the code yourself to achieve a better result.

# %% [markdown]
# ## Import packages you need

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 666  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# ## Basic Function
# Do not modify this part

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()
    
def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('Truth value')
    plt.ylabel('predicted value')
    plt.title('Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# ## Data and Preprocess
# The function below used to:
# 1. Read the csv files into python
# 2. Choose features (you can choose yourself)
# 3. Split data into training and validation sets.
# 4. Normalization

# %%
class Dataprocess(Dataset):
    def __init__(self,
                 path,
                 mode='train',
                 modify=False):
        self.mode = mode

        # Read csv file
        with open(path, 'r') as f:
            data = list(csv.reader(f))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if modify == False:
            feats = list(range(93))
        else:
            # Hint:Feature Selection
            
            
            
            pass

        if mode == 'test':
            # Testing set
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training set
            target = data[:, -1]
            data = data[:, feats]

            # Splitting data into training and validation sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# ## Dataloader
# Loads data into batches.

# %%
def dataloader(path, mode, batch_size, n_jobs=0, modify=False):
    dataset = Dataprocess(path, mode=mode, modify=modify)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    return dataloader

# %% [markdown]
# ## Define DNN by pytorch
# The DNN consists of 2 fully-connected layers with ReLU activation function

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()
        
        # Try to modify this DNN to achieve better performance
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        # Loss function MSE
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # You may try regularization here
        
        return self.criterion(pred, target)

# %% [markdown]
# ## Training

# %%
def train(tr_set, dv_set, model, config, device):

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## Validation

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## Testing

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# ## Hyper-parameters for DNN

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
modify = False                        # Need selection

# Tune these hyper-parameters to improve your model
config = {
    'n_epochs': 3000,                # maximum number of epochs
    'batch_size': 270,               # mini-batch size for dataloader
    'optimizer': 'SGD',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.001,                 # learning rate of SGD
    },
    'early_stop': 200,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# ## Read the dataset

# %%
train_path = '/Users/ziruliu/Desktop/Data/HW1.train.csv'  # path to training data
test_path = '/Users/ziruliu/Desktop/Data/HW1.test.csv'   # path to testing data

train_set = dataloader(train_path, 'train', config['batch_size'], modify=modify)
validation_set = dataloader(train_path, 'dev', config['batch_size'], modify=modify)
test_set = dataloader(test_path, 'test', config['batch_size'], modify=modify)
# Out:
# Finished reading the train set of COVID19 Dataset (1800 samples found, each dim = 93)
# Finished reading the dev set of COVID19 Dataset (200 samples found, each dim = 93)
# Finished reading the test set of COVID19 Dataset (650 samples found, each dim = 93)

# %% [markdown]
# ## Try to train your DNN

# %%
model = NeuralNet(train_set.dataset.dim).to(device)  # Construct model and move to device

# %%
model_loss, model_loss_record = train(train_set, validation_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 278.1822)
# Saving model (epoch =    2, loss = 223.2045)
# Saving model (epoch =    3, loss = 138.8106)
# Saving model (epoch =    4, loss = 74.6075)
# Saving model (epoch =    5, loss = 48.4086)
# Saving model (epoch =    6, loss = 36.3728)
# Saving model (epoch =    7, loss = 30.4644)
# Saving model (epoch =    8, loss = 27.5138)
# Saving model (epoch =    9, loss = 25.8233)
# Saving model (epoch =   10, loss = 24.6467)
# Saving model (epoch =   11, loss = 23.6257)
# Saving model (epoch =   12, loss = 22.6367)
# Saving model (epoch =   13, loss = 21.7962)
# Saving model (epoch =   14, loss = 21.0081)
# Saving model (epoch =   15, loss = 20.2546)
# Saving model (epoch =   16, loss = 19.5754)
# Saving model (epoch =   17, loss = 18.9373)
# Saving model (epoch =   18, loss = 18.2877)
# Saving model (epoch =   19, loss = 17.7280)
# Saving model (epoch =   20, loss = 17.1366)
# Saving model (epoch =   21, loss = 16.6035)
# Saving model (epoch =   22, loss = 16.0721)
# Saving model (epoch =   23, loss = 15.5495)
# Saving model (epoch =   24, loss = 15.0671)
# Saving model (epoch =   25, loss = 14.5911)
# Saving model (epoch =   26, loss = 14.1263)
# Saving model (epoch =   27, loss = 13.6923)
# Saving model (epoch =   28, loss = 13.2427)
# Saving model (epoch =   29, loss = 12.8130)
# Saving model (epoch =   30, loss = 12.4199)
# Saving model (epoch =   31, loss = 12.0216)
# Saving model (epoch =   32, loss = 11.6487)
# Saving model (epoch =   33, loss = 11.2817)
# Saving model (epoch =   34, loss = 10.9356)
# Saving model (epoch =   35, loss = 10.5819)
# Saving model (epoch =   36, loss = 10.2671)
# Saving model (epoch =   37, loss = 9.9264)
# Saving model (epoch =   38, loss = 9.6333)
# Saving model (epoch =   39, loss = 9.3583)
# Saving model (epoch =   40, loss = 9.0651)
# Saving model (epoch =   41, loss = 8.7771)
# Saving model (epoch =   42, loss = 8.5174)
# Saving model (epoch =   43, loss = 8.2563)
# Saving model (epoch =   44, loss = 8.0228)
# Saving model (epoch =   45, loss = 7.7994)
# Saving model (epoch =   46, loss = 7.5904)
# Saving model (epoch =   47, loss = 7.3710)
# Saving model (epoch =   48, loss = 7.1705)
# Saving model (epoch =   49, loss = 6.9642)
# Saving model (epoch =   50, loss = 6.7794)
# Saving model (epoch =   51, loss = 6.6251)
# Saving model (epoch =   52, loss = 6.4577)
# Saving model (epoch =   53, loss = 6.2710)
# Saving model (epoch =   54, loss = 6.1233)
# Saving model (epoch =   55, loss = 5.9865)
# Saving model (epoch =   56, loss = 5.8358)
# Saving model (epoch =   57, loss = 5.7024)
# Saving model (epoch =   58, loss = 5.5777)
# Saving model (epoch =   59, loss = 5.4521)
# Saving model (epoch =   60, loss = 5.3214)
# Saving model (epoch =   61, loss = 5.1986)
# Saving model (epoch =   62, loss = 5.0966)
# Saving model (epoch =   63, loss = 5.0031)
# Saving model (epoch =   64, loss = 4.9099)
# Saving model (epoch =   65, loss = 4.8009)
# Saving model (epoch =   66, loss = 4.7138)
# Saving model (epoch =   67, loss = 4.6249)
# Saving model (epoch =   68, loss = 4.5326)
# Saving model (epoch =   69, loss = 4.4442)
# Saving model (epoch =   70, loss = 4.3594)
# Saving model (epoch =   71, loss = 4.2964)
# Saving model (epoch =   72, loss = 4.2136)
# Saving model (epoch =   73, loss = 4.1466)
# Saving model (epoch =   74, loss = 4.0755)
# Saving model (epoch =   75, loss = 4.0079)
# Saving model (epoch =   76, loss = 3.9585)
# Saving model (epoch =   77, loss = 3.9021)
# Saving model (epoch =   78, loss = 3.8323)
# Saving model (epoch =   79, loss = 3.7763)
# Saving model (epoch =   80, loss = 3.7299)
# Saving model (epoch =   81, loss = 3.6705)
# Saving model (epoch =   82, loss = 3.6175)
# Saving model (epoch =   83, loss = 3.5677)
# Saving model (epoch =   84, loss = 3.5207)
# Saving model (epoch =   85, loss = 3.4796)
# Saving model (epoch =   86, loss = 3.4253)
# Saving model (epoch =   87, loss = 3.3899)
# Saving model (epoch =   88, loss = 3.3515)
# Saving model (epoch =   89, loss = 3.3167)
# Saving model (epoch =   90, loss = 3.2817)
# Saving model (epoch =   91, loss = 3.2386)
# Saving model (epoch =   92, loss = 3.2073)
# Saving model (epoch =   93, loss = 3.1773)
# Saving model (epoch =   94, loss = 3.1528)
# Saving model (epoch =   95, loss = 3.1143)
# Saving model (epoch =   96, loss = 3.0719)
# Saving model (epoch =   97, loss = 3.0420)
# Saving model (epoch =   98, loss = 3.0102)
# Saving model (epoch =   99, loss = 2.9846)
# Saving model (epoch =  100, loss = 2.9537)
# Saving model (epoch =  101, loss = 2.9198)
# Saving model (epoch =  102, loss = 2.9035)
# Saving model (epoch =  103, loss = 2.8690)
# Saving model (epoch =  104, loss = 2.8397)
# Saving model (epoch =  105, loss = 2.8204)
# Saving model (epoch =  106, loss = 2.7863)
# Saving model (epoch =  107, loss = 2.7651)
# Saving model (epoch =  108, loss = 2.7277)
# Saving model (epoch =  109, loss = 2.7079)
# Saving model (epoch =  110, loss = 2.6887)
# Saving model (epoch =  111, loss = 2.6766)
# Saving model (epoch =  112, loss = 2.6337)
# Saving model (epoch =  113, loss = 2.6008)
# Saving model (epoch =  114, loss = 2.5798)
# Saving model (epoch =  115, loss = 2.5635)
# Saving model (epoch =  116, loss = 2.5426)
# Saving model (epoch =  117, loss = 2.5118)
# Saving model (epoch =  118, loss = 2.4858)
# Saving model (epoch =  119, loss = 2.4709)
# Saving model (epoch =  120, loss = 2.4476)
# Saving model (epoch =  121, loss = 2.4306)
# Saving model (epoch =  122, loss = 2.4030)
# Saving model (epoch =  123, loss = 2.3868)
# Saving model (epoch =  124, loss = 2.3674)
# Saving model (epoch =  125, loss = 2.3473)
# Saving model (epoch =  126, loss = 2.3312)
# Saving model (epoch =  127, loss = 2.3100)
# Saving model (epoch =  128, loss = 2.2992)
# Saving model (epoch =  129, loss = 2.2770)
# Saving model (epoch =  130, loss = 2.2584)
# Saving model (epoch =  131, loss = 2.2529)
# Saving model (epoch =  132, loss = 2.2195)
# Saving model (epoch =  133, loss = 2.2031)
# Saving model (epoch =  134, loss = 2.1902)
# Saving model (epoch =  135, loss = 2.1686)
# Saving model (epoch =  136, loss = 2.1445)
# Saving model (epoch =  137, loss = 2.1432)
# Saving model (epoch =  138, loss = 2.1100)
# Saving model (epoch =  139, loss = 2.1010)
# Saving model (epoch =  140, loss = 2.0865)
# Saving model (epoch =  141, loss = 2.0667)
# Saving model (epoch =  142, loss = 2.0558)
# Saving model (epoch =  144, loss = 2.0239)
# Saving model (epoch =  145, loss = 2.0067)
# Saving model (epoch =  146, loss = 1.9986)
# Saving model (epoch =  147, loss = 1.9812)
# Saving model (epoch =  148, loss = 1.9675)
# Saving model (epoch =  149, loss = 1.9616)
# Saving model (epoch =  150, loss = 1.9426)
# Saving model (epoch =  151, loss = 1.9284)
# Saving model (epoch =  152, loss = 1.9145)
# Saving model (epoch =  153, loss = 1.9017)
# Saving model (epoch =  154, loss = 1.8885)
# Saving model (epoch =  155, loss = 1.8788)
# Saving model (epoch =  156, loss = 1.8629)
# Saving model (epoch =  157, loss = 1.8530)
# Saving model (epoch =  158, loss = 1.8430)
# Saving model (epoch =  159, loss = 1.8305)
# Saving model (epoch =  160, loss = 1.8270)
# Saving model (epoch =  161, loss = 1.8150)
# Saving model (epoch =  162, loss = 1.8004)
# Saving model (epoch =  163, loss = 1.7872)
# Saving model (epoch =  164, loss = 1.7766)
# Saving model (epoch =  165, loss = 1.7619)
# Saving model (epoch =  167, loss = 1.7461)
# Saving model (epoch =  168, loss = 1.7316)
# Saving model (epoch =  169, loss = 1.7183)
# Saving model (epoch =  170, loss = 1.7138)
# Saving model (epoch =  171, loss = 1.7137)
# Saving model (epoch =  172, loss = 1.7022)
# Saving model (epoch =  173, loss = 1.6911)
# Saving model (epoch =  174, loss = 1.6851)
# Saving model (epoch =  175, loss = 1.6703)
# Saving model (epoch =  176, loss = 1.6670)
# Saving model (epoch =  177, loss = 1.6518)
# Saving model (epoch =  178, loss = 1.6476)
# Saving model (epoch =  180, loss = 1.6436)
# Saving model (epoch =  181, loss = 1.6260)
# Saving model (epoch =  183, loss = 1.6078)
# Saving model (epoch =  184, loss = 1.6076)
# Saving model (epoch =  185, loss = 1.5986)
# Saving model (epoch =  186, loss = 1.5934)
# Saving model (epoch =  187, loss = 1.5861)
# Saving model (epoch =  188, loss = 1.5778)
# Saving model (epoch =  189, loss = 1.5731)
# Saving model (epoch =  190, loss = 1.5677)
# Saving model (epoch =  191, loss = 1.5592)
# Saving model (epoch =  193, loss = 1.5511)
# Saving model (epoch =  194, loss = 1.5425)
# Saving model (epoch =  195, loss = 1.5378)
# Saving model (epoch =  196, loss = 1.5320)
# Saving model (epoch =  197, loss = 1.5198)
# Saving model (epoch =  200, loss = 1.5114)
# Saving model (epoch =  201, loss = 1.5049)
# Saving model (epoch =  202, loss = 1.4984)
# Saving model (epoch =  204, loss = 1.4903)
# Saving model (epoch =  205, loss = 1.4810)
# Saving model (epoch =  206, loss = 1.4774)
# Saving model (epoch =  208, loss = 1.4637)
# Saving model (epoch =  210, loss = 1.4608)
# Saving model (epoch =  211, loss = 1.4552)
# Saving model (epoch =  212, loss = 1.4549)
# Saving model (epoch =  213, loss = 1.4454)
# Saving model (epoch =  214, loss = 1.4397)
# Saving model (epoch =  215, loss = 1.4362)
# Saving model (epoch =  216, loss = 1.4313)
# Saving model (epoch =  217, loss = 1.4182)
# Saving model (epoch =  218, loss = 1.4175)
# Saving model (epoch =  220, loss = 1.4076)
# Saving model (epoch =  221, loss = 1.4061)
# Saving model (epoch =  222, loss = 1.4027)
# Saving model (epoch =  223, loss = 1.3988)
# Saving model (epoch =  224, loss = 1.3968)
# Saving model (epoch =  226, loss = 1.3868)
# Saving model (epoch =  227, loss = 1.3796)
# Saving model (epoch =  230, loss = 1.3728)
# Saving model (epoch =  231, loss = 1.3685)
# Saving model (epoch =  233, loss = 1.3623)
# Saving model (epoch =  234, loss = 1.3570)
# Saving model (epoch =  235, loss = 1.3527)
# Saving model (epoch =  238, loss = 1.3492)
# Saving model (epoch =  240, loss = 1.3400)
# Saving model (epoch =  241, loss = 1.3356)
# Saving model (epoch =  243, loss = 1.3338)
# Saving model (epoch =  245, loss = 1.3281)
# Saving model (epoch =  246, loss = 1.3226)
# Saving model (epoch =  248, loss = 1.3189)
# Saving model (epoch =  249, loss = 1.3125)
# Saving model (epoch =  253, loss = 1.3039)
# Saving model (epoch =  254, loss = 1.3027)
# Saving model (epoch =  255, loss = 1.3021)
# Saving model (epoch =  256, loss = 1.2926)
# Saving model (epoch =  257, loss = 1.2889)
# Saving model (epoch =  258, loss = 1.2847)
# Saving model (epoch =  262, loss = 1.2841)
# Saving model (epoch =  263, loss = 1.2812)
# Saving model (epoch =  266, loss = 1.2733)
# Saving model (epoch =  269, loss = 1.2655)
# Saving model (epoch =  270, loss = 1.2649)
# Saving model (epoch =  271, loss = 1.2633)
# Saving model (epoch =  273, loss = 1.2556)
# Saving model (epoch =  274, loss = 1.2540)
# Saving model (epoch =  275, loss = 1.2526)
# Saving model (epoch =  278, loss = 1.2514)
# Saving model (epoch =  279, loss = 1.2508)
# Saving model (epoch =  280, loss = 1.2469)
# Saving model (epoch =  281, loss = 1.2433)
# Saving model (epoch =  282, loss = 1.2420)
# Saving model (epoch =  283, loss = 1.2401)
# Saving model (epoch =  285, loss = 1.2376)
# Saving model (epoch =  286, loss = 1.2338)
# Saving model (epoch =  289, loss = 1.2273)
# Saving model (epoch =  291, loss = 1.2261)
# Saving model (epoch =  294, loss = 1.2236)
# Saving model (epoch =  296, loss = 1.2233)
# Saving model (epoch =  297, loss = 1.2191)
# Saving model (epoch =  301, loss = 1.2157)
# Saving model (epoch =  302, loss = 1.2108)
# Saving model (epoch =  305, loss = 1.2089)
# Saving model (epoch =  308, loss = 1.2023)
# Saving model (epoch =  310, loss = 1.2015)
# Saving model (epoch =  312, loss = 1.1986)
# Saving model (epoch =  314, loss = 1.1973)
# Saving model (epoch =  316, loss = 1.1903)
# Saving model (epoch =  317, loss = 1.1902)
# Saving model (epoch =  319, loss = 1.1883)
# Saving model (epoch =  322, loss = 1.1874)
# Saving model (epoch =  323, loss = 1.1861)
# Saving model (epoch =  325, loss = 1.1851)
# Saving model (epoch =  327, loss = 1.1797)
# Saving model (epoch =  330, loss = 1.1789)
# Saving model (epoch =  332, loss = 1.1685)
# Saving model (epoch =  337, loss = 1.1663)
# Saving model (epoch =  339, loss = 1.1656)
# Saving model (epoch =  340, loss = 1.1630)
# Saving model (epoch =  342, loss = 1.1620)
# Saving model (epoch =  343, loss = 1.1615)
# Saving model (epoch =  344, loss = 1.1570)
# Saving model (epoch =  348, loss = 1.1514)
# Saving model (epoch =  350, loss = 1.1502)
# Saving model (epoch =  352, loss = 1.1488)
# Saving model (epoch =  356, loss = 1.1459)
# Saving model (epoch =  361, loss = 1.1416)
# Saving model (epoch =  362, loss = 1.1384)
# Saving model (epoch =  363, loss = 1.1348)
# Saving model (epoch =  364, loss = 1.1346)
# Saving model (epoch =  365, loss = 1.1341)
# Saving model (epoch =  367, loss = 1.1317)
# Saving model (epoch =  368, loss = 1.1298)
# Saving model (epoch =  369, loss = 1.1265)
# Saving model (epoch =  373, loss = 1.1264)
# Saving model (epoch =  374, loss = 1.1182)
# Saving model (epoch =  382, loss = 1.1176)
# Saving model (epoch =  383, loss = 1.1143)
# Saving model (epoch =  386, loss = 1.1135)
# Saving model (epoch =  387, loss = 1.1095)
# Saving model (epoch =  391, loss = 1.1064)
# Saving model (epoch =  393, loss = 1.1032)
# Saving model (epoch =  394, loss = 1.1029)
# Saving model (epoch =  396, loss = 1.1001)
# Saving model (epoch =  400, loss = 1.0989)
# Saving model (epoch =  403, loss = 1.0947)
# Saving model (epoch =  404, loss = 1.0944)
# Saving model (epoch =  405, loss = 1.0935)
# Saving model (epoch =  407, loss = 1.0883)
# Saving model (epoch =  411, loss = 1.0856)
# Saving model (epoch =  412, loss = 1.0848)
# Saving model (epoch =  413, loss = 1.0821)
# Saving model (epoch =  417, loss = 1.0805)
# Saving model (epoch =  419, loss = 1.0777)
# Saving model (epoch =  421, loss = 1.0733)
# Saving model (epoch =  422, loss = 1.0720)
# Saving model (epoch =  429, loss = 1.0671)
# Saving model (epoch =  431, loss = 1.0639)
# Saving model (epoch =  432, loss = 1.0638)
# Saving model (epoch =  437, loss = 1.0610)
# Saving model (epoch =  438, loss = 1.0606)
# Saving model (epoch =  441, loss = 1.0587)
# Saving model (epoch =  445, loss = 1.0581)
# Saving model (epoch =  446, loss = 1.0553)
# Saving model (epoch =  449, loss = 1.0525)
# Saving model (epoch =  450, loss = 1.0492)
# Saving model (epoch =  458, loss = 1.0470)
# Saving model (epoch =  461, loss = 1.0465)
# Saving model (epoch =  462, loss = 1.0462)
# Saving model (epoch =  463, loss = 1.0441)
# Saving model (epoch =  465, loss = 1.0409)
# Saving model (epoch =  466, loss = 1.0409)
# Saving model (epoch =  470, loss = 1.0384)
# Saving model (epoch =  473, loss = 1.0371)
# Saving model (epoch =  474, loss = 1.0323)
# Saving model (epoch =  484, loss = 1.0309)
# Saving model (epoch =  487, loss = 1.0306)
# Saving model (epoch =  490, loss = 1.0292)
# Saving model (epoch =  493, loss = 1.0260)
# Saving model (epoch =  496, loss = 1.0233)
# Saving model (epoch =  504, loss = 1.0214)
# Saving model (epoch =  506, loss = 1.0206)
# Saving model (epoch =  508, loss = 1.0188)
# Saving model (epoch =  512, loss = 1.0156)
# Saving model (epoch =  513, loss = 1.0147)
# Saving model (epoch =  517, loss = 1.0144)
# Saving model (epoch =  520, loss = 1.0140)
# Saving model (epoch =  528, loss = 1.0112)
# Saving model (epoch =  529, loss = 1.0095)
# Saving model (epoch =  533, loss = 1.0059)
# Saving model (epoch =  536, loss = 1.0049)
# Saving model (epoch =  540, loss = 1.0033)
# Saving model (epoch =  542, loss = 1.0028)
# Saving model (epoch =  546, loss = 1.0026)
# Saving model (epoch =  547, loss = 1.0000)
# Saving model (epoch =  550, loss = 0.9989)
# Saving model (epoch =  555, loss = 0.9987)
# Saving model (epoch =  556, loss = 0.9968)
# Saving model (epoch =  560, loss = 0.9955)
# Saving model (epoch =  561, loss = 0.9926)
# Saving model (epoch =  567, loss = 0.9884)
# Saving model (epoch =  576, loss = 0.9883)
# Saving model (epoch =  577, loss = 0.9873)
# Saving model (epoch =  579, loss = 0.9848)
# Saving model (epoch =  580, loss = 0.9844)
# Saving model (epoch =  590, loss = 0.9826)
# Saving model (epoch =  591, loss = 0.9817)
# Saving model (epoch =  595, loss = 0.9815)
# Saving model (epoch =  598, loss = 0.9810)
# Saving model (epoch =  600, loss = 0.9799)
# Saving model (epoch =  603, loss = 0.9776)
# Saving model (epoch =  604, loss = 0.9758)
# Saving model (epoch =  605, loss = 0.9755)
# Saving model (epoch =  612, loss = 0.9748)
# Saving model (epoch =  614, loss = 0.9743)
# Saving model (epoch =  618, loss = 0.9734)
# Saving model (epoch =  621, loss = 0.9729)
# Saving model (epoch =  623, loss = 0.9722)
# Saving model (epoch =  624, loss = 0.9715)
# Saving model (epoch =  625, loss = 0.9693)
# Saving model (epoch =  631, loss = 0.9683)
# Saving model (epoch =  634, loss = 0.9666)
# Saving model (epoch =  635, loss = 0.9664)
# Saving model (epoch =  640, loss = 0.9663)
# Saving model (epoch =  641, loss = 0.9621)
# Saving model (epoch =  648, loss = 0.9618)
# Saving model (epoch =  649, loss = 0.9589)
# Saving model (epoch =  661, loss = 0.9581)
# Saving model (epoch =  662, loss = 0.9555)
# Saving model (epoch =  671, loss = 0.9550)
# Saving model (epoch =  675, loss = 0.9536)
# Saving model (epoch =  676, loss = 0.9524)
# Saving model (epoch =  685, loss = 0.9511)
# Saving model (epoch =  687, loss = 0.9475)
# Saving model (epoch =  693, loss = 0.9469)
# Saving model (epoch =  697, loss = 0.9468)
# Saving model (epoch =  698, loss = 0.9465)
# Saving model (epoch =  699, loss = 0.9460)
# Saving model (epoch =  700, loss = 0.9460)
# Saving model (epoch =  701, loss = 0.9443)
# Saving model (epoch =  705, loss = 0.9435)
# Saving model (epoch =  710, loss = 0.9410)
# Saving model (epoch =  711, loss = 0.9407)
# Saving model (epoch =  714, loss = 0.9387)
# Saving model (epoch =  717, loss = 0.9375)
# Saving model (epoch =  722, loss = 0.9362)
# Saving model (epoch =  729, loss = 0.9342)
# Saving model (epoch =  732, loss = 0.9341)
# Saving model (epoch =  735, loss = 0.9329)
# Saving model (epoch =  737, loss = 0.9304)
# Saving model (epoch =  744, loss = 0.9288)
# Saving model (epoch =  754, loss = 0.9277)
# Saving model (epoch =  756, loss = 0.9276)
# Saving model (epoch =  761, loss = 0.9258)
# Saving model (epoch =  763, loss = 0.9255)
# Saving model (epoch =  767, loss = 0.9250)
# Saving model (epoch =  768, loss = 0.9245)
# Saving model (epoch =  769, loss = 0.9243)
# Saving model (epoch =  770, loss = 0.9226)
# Saving model (epoch =  771, loss = 0.9220)
# Saving model (epoch =  780, loss = 0.9211)
# Saving model (epoch =  782, loss = 0.9206)
# Saving model (epoch =  784, loss = 0.9190)
# Saving model (epoch =  789, loss = 0.9171)
# Saving model (epoch =  792, loss = 0.9169)
# Saving model (epoch =  793, loss = 0.9164)
# Saving model (epoch =  794, loss = 0.9154)
# Saving model (epoch =  795, loss = 0.9132)
# Saving model (epoch =  801, loss = 0.9123)
# Saving model (epoch =  807, loss = 0.9113)
# Saving model (epoch =  814, loss = 0.9108)
# Saving model (epoch =  816, loss = 0.9107)
# Saving model (epoch =  819, loss = 0.9080)
# Saving model (epoch =  820, loss = 0.9065)
# Saving model (epoch =  827, loss = 0.9042)
# Saving model (epoch =  836, loss = 0.9039)
# Saving model (epoch =  847, loss = 0.9026)
# Saving model (epoch =  850, loss = 0.9013)
# Saving model (epoch =  851, loss = 0.9002)
# Saving model (epoch =  854, loss = 0.8992)
# Saving model (epoch =  865, loss = 0.8990)
# Saving model (epoch =  866, loss = 0.8984)
# Saving model (epoch =  871, loss = 0.8977)
# Saving model (epoch =  874, loss = 0.8973)
# Saving model (epoch =  877, loss = 0.8965)
# Saving model (epoch =  878, loss = 0.8962)
# Saving model (epoch =  880, loss = 0.8927)
# Saving model (epoch =  882, loss = 0.8921)
# Saving model (epoch =  888, loss = 0.8919)
# Saving model (epoch =  889, loss = 0.8914)
# Saving model (epoch =  895, loss = 0.8898)
# Saving model (epoch =  901, loss = 0.8893)
# Saving model (epoch =  907, loss = 0.8881)
# Saving model (epoch =  908, loss = 0.8874)
# Saving model (epoch =  915, loss = 0.8842)
# Saving model (epoch =  924, loss = 0.8839)
# Saving model (epoch =  931, loss = 0.8835)
# Saving model (epoch =  939, loss = 0.8828)
# Saving model (epoch =  940, loss = 0.8822)
# Saving model (epoch =  942, loss = 0.8817)
# Saving model (epoch =  971, loss = 0.8817)
# Saving model (epoch =  973, loss = 0.8808)
# Saving model (epoch =  974, loss = 0.8806)
# Saving model (epoch =  980, loss = 0.8796)
# Saving model (epoch =  982, loss = 0.8787)
# Saving model (epoch =  993, loss = 0.8776)
# Saving model (epoch =  997, loss = 0.8756)
# Saving model (epoch = 1006, loss = 0.8733)
# Saving model (epoch = 1026, loss = 0.8705)
# Saving model (epoch = 1027, loss = 0.8699)
# Saving model (epoch = 1057, loss = 0.8685)
# Saving model (epoch = 1077, loss = 0.8673)
# Saving model (epoch = 1080, loss = 0.8667)
# Saving model (epoch = 1082, loss = 0.8665)
# Saving model (epoch = 1085, loss = 0.8661)
# Saving model (epoch = 1087, loss = 0.8647)
# Saving model (epoch = 1088, loss = 0.8630)
# Saving model (epoch = 1089, loss = 0.8625)
# Saving model (epoch = 1135, loss = 0.8621)
# Saving model (epoch = 1145, loss = 0.8612)
# Saving model (epoch = 1149, loss = 0.8604)
# Saving model (epoch = 1151, loss = 0.8600)
# Saving model (epoch = 1155, loss = 0.8596)
# Saving model (epoch = 1156, loss = 0.8594)
# Saving model (epoch = 1158, loss = 0.8594)
# Saving model (epoch = 1168, loss = 0.8576)
# Saving model (epoch = 1169, loss = 0.8570)
# Saving model (epoch = 1171, loss = 0.8555)
# Saving model (epoch = 1178, loss = 0.8551)
# Saving model (epoch = 1195, loss = 0.8550)
# Saving model (epoch = 1215, loss = 0.8549)
# Saving model (epoch = 1217, loss = 0.8544)
# Saving model (epoch = 1219, loss = 0.8540)
# Saving model (epoch = 1228, loss = 0.8539)
# Saving model (epoch = 1230, loss = 0.8527)
# Saving model (epoch = 1236, loss = 0.8518)
# Saving model (epoch = 1237, loss = 0.8516)
# Saving model (epoch = 1248, loss = 0.8512)
# Saving model (epoch = 1262, loss = 0.8500)
# Saving model (epoch = 1275, loss = 0.8496)
# Saving model (epoch = 1276, loss = 0.8492)
# Saving model (epoch = 1293, loss = 0.8480)
# Saving model (epoch = 1334, loss = 0.8467)
# Saving model (epoch = 1351, loss = 0.8463)
# Saving model (epoch = 1354, loss = 0.8462)
# Saving model (epoch = 1355, loss = 0.8453)
# Saving model (epoch = 1370, loss = 0.8448)
# Saving model (epoch = 1371, loss = 0.8436)
# Saving model (epoch = 1390, loss = 0.8434)
# Saving model (epoch = 1408, loss = 0.8430)
# Saving model (epoch = 1422, loss = 0.8429)
# Saving model (epoch = 1424, loss = 0.8417)
# Saving model (epoch = 1433, loss = 0.8410)
# Saving model (epoch = 1462, loss = 0.8400)
# Saving model (epoch = 1499, loss = 0.8392)
# Saving model (epoch = 1506, loss = 0.8390)
# Saving model (epoch = 1517, loss = 0.8384)
# Saving model (epoch = 1550, loss = 0.8365)
# Saving model (epoch = 1585, loss = 0.8365)
# Saving model (epoch = 1591, loss = 0.8355)
# Saving model (epoch = 1596, loss = 0.8350)
# Saving model (epoch = 1600, loss = 0.8350)
# Saving model (epoch = 1623, loss = 0.8332)
# Saving model (epoch = 1670, loss = 0.8316)
# Saving model (epoch = 1689, loss = 0.8303)
# Saving model (epoch = 1710, loss = 0.8302)
# Saving model (epoch = 1721, loss = 0.8295)
# Saving model (epoch = 1740, loss = 0.8290)
# Saving model (epoch = 1788, loss = 0.8278)
# Saving model (epoch = 1826, loss = 0.8274)
# Saving model (epoch = 1829, loss = 0.8271)
# Saving model (epoch = 1839, loss = 0.8270)
# Saving model (epoch = 1844, loss = 0.8261)
# Saving model (epoch = 1879, loss = 0.8254)
# Saving model (epoch = 1888, loss = 0.8247)
# Saving model (epoch = 1901, loss = 0.8236)
# Saving model (epoch = 1944, loss = 0.8236)
# Saving model (epoch = 1945, loss = 0.8230)
# Saving model (epoch = 1947, loss = 0.8223)
# Saving model (epoch = 1968, loss = 0.8222)
# Saving model (epoch = 2017, loss = 0.8218)
# Saving model (epoch = 2104, loss = 0.8215)
# Saving model (epoch = 2112, loss = 0.8209)
# Saving model (epoch = 2169, loss = 0.8205)
# Saving model (epoch = 2210, loss = 0.8198)
# Saving model (epoch = 2225, loss = 0.8196)
# Saving model (epoch = 2250, loss = 0.8195)
# Saving model (epoch = 2255, loss = 0.8176)
# Finished training after 2456 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(train_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(validation_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# ## Testing
# Get the prediction result and save it to csv file named 'prediction.csv'

# %%
def save_pred(preds, file):
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(test_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'prediction.csv')         # save prediction file to pred.csv
# Out:
# Saving results to prediction.csv

# %% [markdown]
# ## Hints for better result
# * Feature selection
# * DNN architecture
# * Training (mini-batch/optimizer/learning rate)
# * Regularization
